# %% [markdown]
# <a href="https://colab.research.google.com/github/Polineska/SpeechRecognition/blob/main/%D0%93%D1%80%D0%B0%D1%84%D0%B8%D0%BA%D0%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

systems = ['whisper_medium', 'google STT', 'vosk']
noisy_wer = [36.25, 58.37, 87.50]
clean_wer = [22.63, 24.71, 19.42]

x = np.arange(len(systems)) # Создание графика
width = 0.35

fig, ax = plt.subplots()

bar1 = ax.bar(x - width/2, noisy_wer, width, label='Зашумленные')
bar2 = ax.bar(x + width/2, clean_wer, width, label='Незашумленные')

ax.set_ylabel('WER (%)')
ax.set_title('Анализ систем распознавания речи на датасете Golos')
ax.set_xticks(x)
ax.set_xticklabels(systems)
ax.legend()

for bar in bar1 + bar2: # Добавление значений WER над столбцами
    height = bar.get_height()
    ax.annotate(f'{height:.2f}%',
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),
                textcoords="offset points",
                ha='center', va='bottom')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

systems = ['whisper_medium', 'google STT', 'vosk']
noisy_wer = [5.87, 19.79, 25.78]
clean_wer = [3.02, 9.62, 9.91]

x = np.arange(len(systems))  # Создание графика
width = 0.35

fig, ax = plt.subplots()

bar1 = ax.bar(x - width/2, noisy_wer, width, label='Зашумленные')
bar2 = ax.bar(x + width/2, clean_wer, width, label='Незашумленные')

ax.set_ylabel('WER (%)')
ax.set_title('Анализ систем распознавания речи на датасете LibriSpeech')
ax.set_xticks(x)
ax.set_xticklabels(systems)
ax.legend()

for bar in bar1 + bar2:  # Добавление значений WER над столбцами
    height = bar.get_height()
    ax.annotate(f'{height:.2f}%',
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),
                textcoords="offset points",
                ha='center', va='bottom')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

models = [ 'vosk', 'whisper_medium', 'google STT']
book = [ 13.45, 3.68, 8.42]
speech_defects = [ 45.58, 11.54, 30.29]
links = [ 7.25, 4.35, 5.80]
noise = [ 23.66, 14.04, 22.72]
parasier = [9.68, 16.19, 29.87]
termin = [27.42, 6.45, 11.45]

x = np.arange(len(models))
width = 0.15

fig, ax = plt.subplots(figsize=(12, 8))

rects1 = ax.bar(x - 2.5*width, book, width, label='book')
rects2 = ax.bar(x - 1.5*width, speech_defects, width, label='speech_defects')
rects3 = ax.bar(x - 0.5*width, links, width, label='links')
rects4 = ax.bar(x + 0.5*width, noise, width, label='noise')
rects5 = ax.bar(x + 1.5*width, parasier, width, label='parasier')
rects6 = ax.bar(x + 2.5*width, termin, width, label='termin')

ax.set_xlabel('Модели Whisper', fontsize=12)
ax.set_ylabel('WER (%)', fontsize=12)
ax.set_title('Значения WER для русскоязычных аудиоданных', fontsize=14)
ax.set_xticks(x)
ax.set_xticklabels(models)
ax.legend()


fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
models = ['whisper_medium', 'google STT', 'vosk']
wer = [9.37,18.09,17.23 ]
sf = [0.18,	0.16, 0.18]

# Создание фигуры и осей
fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1, figsize=(8, 6))

# Визуализация WER
ax1.plot(models, wer, marker='o')
ax1.set_xlabel('Модели')
ax1.set_ylabel('WER (%)')
ax1.set_title('Значение WER для русскоязычных аудиоданных ')

# Визуализация SF
ax2.plot(models, sf, marker='o')
ax2.set_xlabel('Модели')
ax2.set_ylabel('SF')
ax2.set_title('Значения SF для русскоязычных аудиоданных')

# Регулировка расстояния между подграфиками
plt.subplots_adjust(hspace=0.5)

# Отображение графика
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

models = ['vosk', 'whisper_medium', 'google STT']
book = [	10.56,	4.79,	4.96]
speech_defects = [35.96,	17.69,	26.26]
links = [6.04, 4.04, 6.71]
noise = [42.50,	9.81,	28.83]
parasier = [19.88,	7.01,	32.27]
termin = [4.75,	4.30,	11.63]

x = np.arange(len(models))
width = 0.15

fig, ax = plt.subplots(figsize=(12, 8))

rects1 = ax.bar(x - 2.5*width, book, width, label='book')
rects2 = ax.bar(x - 1.5*width, speech_defects, width, label='speech_defects')
rects3 = ax.bar(x - 0.5*width, links, width, label='links')
rects4 = ax.bar(x + 0.5*width, noise, width, label='noise')
rects5 = ax.bar(x + 1.5*width, parasier, width, label='parasier')
rects6 = ax.bar(x + 2.5*width, termin, width, label='termin')

ax.set_xlabel('Модели Whisper', fontsize=12)
ax.set_ylabel('WER (%)', fontsize=12)
ax.set_title('Значения WER для англоязычных аудиоданных', fontsize=14)
ax.set_xticks(x)
ax.set_xticklabels(models)
ax.legend()

fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
models = ['whisper_medium', 'google STT', 'vosk']
wer = [7.94 ,18.44,19.94 ]
sf = [0.18,	0.16, 0.18]

# Создание фигуры и осей
fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1, figsize=(8, 6))

# Визуализация WER
ax1.plot(models, wer, marker='o')
ax1.set_xlabel('Модели')
ax1.set_ylabel('WER (%)')
ax1.set_title('Значение WER для англоязычных аудиоданных ')

# Визуализация SF
ax2.plot(models, sf, marker='o')
ax2.set_xlabel('Модели')
ax2.set_ylabel('SF')
ax2.set_title('Значения SF для англоязычных аудиоданных')

# Регулировка расстояния между подграфиками
plt.subplots_adjust(hspace=0.5)

# Отображение графика
plt.show()

# %%
import matplotlib.pyplot as plt

# Данные WER для русского языка
ru_wer_labels = ['book', 'def', 'links', 'noise', 'parasier', 'termin']
ru_wer_values = [3.68, 11.54, 4.35, 14.04, 16.19, 6.45]

# Данные WER для английского языка
en_wer_labels = ['book', 'def', 'links', 'noise', 'parasier', 'termin']
en_wer_values = [4.79, 17.69, 4.04, 9.81, 7.01, 4.30]

# Данные SF для русского языка
ru_sf_labels = ['book', 'def', 'links', 'noise', 'parasier', 'termin']
ru_sf_values = [0.15, 0.23, 0.22, 0.15, 0.16, 0.18]

# Данные SF для английского языка
en_sf_labels = ['book', 'def', 'links', 'noise', 'parasier', 'termin']
en_sf_values = [0.15, 0.19, 0.22, 0.25, 0.16, 0.29]

# Создание subplot для WER
fig, ax = plt.subplots(figsize=(12, 5))

bar_width = 0.4
index = range(len(ru_wer_values))

# График WER для русского языка
bars1 = ax.bar(index, ru_wer_values, bar_width, label='Русский (WER)')

# График WER для английского языка
bars2 = ax.bar([i + bar_width for i in index], en_wer_values, bar_width, label='Английский (WER)')

ax.set_title('WER для русского и английского языков')
ax.set_xlabel('Тип записи')
ax.set_ylabel('WER (%)')
ax.set_xticks([i + bar_width / 2 for i in index])
ax.set_xticklabels(ru_wer_labels)
ax.legend()

# Подписи данных над столбиками
for bar in bars1 + bars2:
    height = bar.get_height()
    ax.annotate('{:.2f}'.format(height),
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),
                textcoords="offset points",
                ha='center', va='bottom')

plt.tight_layout()
plt.show()

# Создание subplot для SF
fig, ax = plt.subplots(figsize=(12, 5))

bar_width = 0.4
index = range(len(ru_sf_values))

# График SF для русского языка
bars1 = ax.bar(index, ru_sf_values, bar_width, label='Русский (SF)')

# График SF для английского языка
bars2 = ax.bar([i + bar_width for i in index], en_sf_values, bar_width, label='Английский (SF)')

ax.set_title('SF для русского и английского языков')
ax.set_xlabel('Тип записи')
ax.set_ylabel('SF')
ax.set_xticks([i + bar_width / 2 for i in index])
ax.set_xticklabels(ru_sf_labels)
ax.legend()

# Подписи данных над столбиками
for bar in bars1 + bars2:
    height = bar.get_height()
    ax.annotate('{:.2f}'.format(height),
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),
                textcoords="offset points",
                ha='center', va='bottom')

plt.tight_layout()
plt.show()
